# %%
# !pip install optuna
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.3 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
def objective(trial):
    x = trial.suggest_uniform('x', -2, 2)
    y = trial.suggest_uniform('y', -2, 2)
    return (1 - x) ** 2 + 100 * (y - x ** 2) ** 2


import optuna

study = optuna.create_study(study_name='optuna_tutorials', direction='minimize')
study.optimize(objective, n_trials=1000)
print(study.best_params, study.best_value)
# Out:
# [I 2025-04-24 21:13:22,693] A new study created in memory with name: optuna_tutorials
# /var/folders/_0/f08g_6v53fx_19c_xz7kcsnr0000gn/T/ipykernel_51588/3646069343.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   x = trial.suggest_uniform('x', -2, 2)
# /var/folders/_0/f08g_6v53fx_19c_xz7kcsnr0000gn/T/ipykernel_51588/3646069343.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   y = trial.suggest_uniform('y', -2, 2)
# [I 2025-04-24 21:13:22,695] Trial 0 finished with value: 217.87810333158242 and parameters: {'x': -1.7931697181974244, 'y': 1.7660567059543095}. Best is trial 0 with value: 217.87810333158242.
# ...
